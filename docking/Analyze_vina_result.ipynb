# %%
from analyse_vina_PfB import analyse_vina
import os

# %%
path= os.getcwd()
residue_ls=[88,118,120,21,122]

test=analyse_vina(path)

test.analyse('test_vina', residue_ls, chain_id='A',center_cutoff=5,N_cutoff=5)

test.gen_pivot_adv(save_csv=False)
test.summary
# Out:
#                              al3_4SRS_0_rp_H al3_pf1018_4_rp_H
# PF4_SRS_conformers_12_vina                []                []
# PF_sub_ZZZZE_cluster_10_vina              []            [6, 2]
